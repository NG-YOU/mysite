# %%
# 딕셔너리 데이터
test = {
    'a' : 1
    'b' : 2
}

# %%
print(a)
print(b)

# %%
# 딕셔너리에 언패킹을 하면

# %%
def func_2(*d):
    print(d)

# %%
# **test -> func_2(a=1, b=2)
# *test -> func_2('a', 'b')
# *test.values() -> func_2(1, 2)
func_2(*test.values())
